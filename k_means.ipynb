# %% [markdown]
# <a href="https://colab.research.google.com/github/Samikshya2002/ML-from-scratch/blob/main/k_means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# k means clustering

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.tail()
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83

# %%
df.shape
# Out:
# (200, 5)

# %%
df = df.iloc[:,[3,4]]
df
# Out:
#      Annual Income (k$)  Spending Score (1-100)
# 0                    15                      39
# 1                    15                      81
# 2                    16                       6
# 3                    16                      77
# 4                    17                      40
# ..                  ...                     ...
# 195                 120                      79
# 196                 126                      28
# 197                 126                      74
# 198                 137                      18
# 199                 137                      83
#
# [200 rows x 2 columns]

# %%
df.shape
# Out:
# (200, 2)

# %%
plt.scatter(df.iloc[:,0], df.iloc[:,1], s=20, c="green")

# %%
from sklearn.cluster import KMeans

wcss= [] #within cluster sum of squares
for i in range(1,11):
  kmeans = KMeans(n_clusters=i, init="k-means++", max_iter=300, n_init=10)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)
plt.plot(range(1,11), wcss)
plt.title("Elbow method")
plt.xlabel("Number of clusters")
plt.ylabel("WCSS")
plt.show()

# %%
kmeans = KMeans(n_clusters=7, init= "k-means++", max_iter=300, n_init=10)
labels = kmeans.fit_predict(df)

# %%
np.unique(labels)
# Out:
# array([0, 1, 2, 3, 4, 5, 6], dtype=int32)

# %%
plt.scatter(df.iloc[labels==0,0], df.iloc[labels==0,1], s=50, c="red")
plt.scatter(df.iloc[labels==1,0], df.iloc[labels==1,1], s=50, c="blue")
plt.scatter(df.iloc[labels==2,0], df.iloc[labels==2,1], s=50, c="green")
plt.scatter(df.iloc[labels==3,0], df.iloc[labels==3,1], s=50, c="yellow")
plt.scatter(df.iloc[labels==4,0], df.iloc[labels==4,1], s=50, c="brown")
plt.scatter(df.iloc[labels==5,0], df.iloc[labels==5,1], s=50, c="indigo")
plt.scatter(df.iloc[labels==6,0], df.iloc[labels==6,1], s=50, c="lavender")
plt.scatter(kmeans.cluster_centers_[:,0], kmeans.cluster_centers_[:,1], s=100,
            c="black")
plt.title("Cluster Result")
plt.xlabel("Annual income")
plt.ylabel("Spending score")
plt.show()
